# %%
# import external libraries
import os
import sys
import random
import numpy as np
import pandas as pd
import torch
import math
import time

# import internal modules
sys.path.insert(1, '../src/')
from models.nn import MLP, TimeSeriesDataset
from utils.data_editor import lag, train_test_split

# %%
# read processed data
df = pd.read_csv("../data/processed/tidy_df.csv", index_col=[0, 1, 2])

# empty list for dataframes
y_test_list = []
y_hat_umlp = []

i = df.index.get_level_values(0).unique()[0]
print(i)

# y : "EPS"
y = df.loc[pd.IndexSlice[i, :, :], "EPS"]

# x, exogenous regressors : 'INV', 'AR', 'CAPX', 'GM', 'SA', 'ETR', 'LF'
#     x = df.loc[pd.IndexSlice[i, :, :], ['INV', 'AR', 'CAPX', 'GM', 'SA', 'ETR', 'LF']]

# Unlike statsmodel SARIMA package, NN needs to prepare lagged inputs manually if needed.
# y_lag and x_lag (lag 4 for now)
num_lag = 4
y_lag = lag(y, num_lag, drop_nan=False, reset_index=False)
#     x_lag = lag(x, num_lag, drop_nan=False, reset_index=False)

# Redefine data name as target (y) and feature (y_lag) (explanatory variable, predictor)
target = y
feature = y_lag

# save simple test data series
_, target_test_dataset = train_test_split(target, ratio=(4,1))
_, feature_test_dataset = train_test_split(feature, ratio=(4,1))

# drop nan caused by lag()
feature = feature.dropna(axis=0)
target = target[feature.index]

# setting torch
dtype = torch.float # double float problem in layer 
device = torch.device("cpu")

# Make data to torch.tensor
target = torch.tensor(target.values, dtype=dtype)
feature = torch.tensor(feature.values, dtype=dtype)
target_test_dataset = torch.tensor(target_test_dataset.values, dtype=dtype)
feature_test_dataset = torch.tensor(feature_test_dataset.values, dtype=dtype)
# Out:
# あらた

# %%
# rolling window data preparation

### ! Hyper-Parameter ! ##########################################################
# all period: 48, train 36, test 12
test_window = len(target_test_dataset)
print("test window: ", test_window)

train_window = len(target) - test_window
print("train window: ", train_window)
##################################################################################

train_dataset = TimeSeriesDataset(feature, target, train_window)
print("len of train dataset: ", len(train_dataset))
#     len(train_dataset) == len(target) - train_window = 48 - 36 = 12 == test_window
# Out:
# test window:  12
# train window:  36
# len of train dataset:  12

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=False)

for num_window, (feature_train, target_train) in enumerate(train_loader):
#     print(feature_train.size(), target_train.size())
    feature_train = feature_train[0] # extract single batch
    target_train = target_train[0] # extract single batch
    if (num_window == 0) | (num_window == 1):
        print("")
        print("WINDOW: ", num_window)
        print("FEATURES: ")
        print(feature_train)
        print(feature_train.size())
        print("TARGET: ")
        print(target_train)
        print(target_train.size())
        
    # mini-batch loader
    batch_dataset = TimeSeriesDataset(feature_train, target_train, train_window=None)
    minibatch_loader = torch.utils.data.DataLoader(batch_dataset, batch_size=1, shuffle=False)
    
    for num_mini_batch, (feature_train_mini_batch, target_train_mini_batch) in enumerate(minibatch_loader):
        if (num_window == 0) | (num_window == 1):
            print("    NUM MINI BATCH: ", num_mini_batch)
            print("    FEATURES BATCH; ")
            print(feature_train_mini_batch)
            print(feature_train_mini_batch.size())
            print("    TARGET BATCH; ")
            print(target_train_mini_batch)
            print(target_train_mini_batch.size())
# Out:
# WINDOW:  0
# FEATURES:
# tensor([[-5.4800e+00,  3.1400e+00,  2.4200e+00,  2.6600e+00],
#         [ 6.7800e+00, -5.4800e+00,  3.1400e+00,  2.4200e+00],
#         [ 6.6600e+00,  6.7800e+00, -5.4800e+00,  3.1400e+00],
#         [ 4.8300e+00,  6.6600e+00,  6.7800e+00, -5.4800e+00],
#         [-1.0100e+00,  4.8300e+00,  6.6600e+00,  6.7800e+00],
#         [-2.8400e+00, -1.0100e+00,  4.8300e+00,  6.6600e+00],
#         [ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 6.7800e+00,  6.6600e+00,  4.8300e+00, -1.0100e+00, -2.8400e+00,
#          8.3300e+00,  9.2400e+00, -1.2000e+00,  4.0600e+00,  7.6100e+00,
#          6.2200e+00,  3.5900e+00,  5.2500e+00,  6.6600e+00,  3.5600e+00,
#          7.4600e+00,  6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01,
#         -6.4877e-02,  3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,
#          4.1860e+01,  8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,
#          9.9700e+01,  6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,
#          6.9340e+01])
# torch.Size([36])
#     NUM MINI BATCH:  0
#     FEATURES BATCH;
# tensor([[-5.4800,  3.1400,  2.4200,  2.6600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.7800])
# torch.Size([1])
#     NUM MINI BATCH:  1
#     FEATURES BATCH;
# tensor([[ 6.7800, -5.4800,  3.1400,  2.4200]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.6600])
# torch.Size([1])
#     NUM MINI BATCH:  2
#     FEATURES BATCH;
# tensor([[ 6.6600,  6.7800, -5.4800,  3.1400]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([4.8300])
# torch.Size([1])
#     NUM MINI BATCH:  3
#     FEATURES BATCH;
# tensor([[ 4.8300,  6.6600,  6.7800, -5.4800]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([-1.0100])
# torch.Size([1])
#     NUM MINI BATCH:  4
#     FEATURES BATCH;
# tensor([[-1.0100,  4.8300,  6.6600,  6.7800]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([-2.8400])
# torch.Size([1])
#     NUM MINI BATCH:  5
#     FEATURES BATCH;
# tensor([[-2.8400, -1.0100,  4.8300,  6.6600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([8.3300])
# torch.Size([1])
#     NUM MINI BATCH:  6
#     FEATURES BATCH;
# tensor([[ 8.3300, -2.8400, -1.0100,  4.8300]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([9.2400])
# torch.Size([1])
#     NUM MINI BATCH:  7
#     FEATURES BATCH;
# tensor([[ 9.2400,  8.3300, -2.8400, -1.0100]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([-1.2000])
# torch.Size([1])
#     NUM MINI BATCH:  8
#     FEATURES BATCH;
# tensor([[-1.2000,  9.2400,  8.3300, -2.8400]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([4.0600])
# torch.Size([1])
#     NUM MINI BATCH:  9
#     FEATURES BATCH;
# tensor([[ 4.0600, -1.2000,  9.2400,  8.3300]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([7.6100])
# torch.Size([1])
#     NUM MINI BATCH:  10
#     FEATURES BATCH;
# tensor([[ 7.6100,  4.0600, -1.2000,  9.2400]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.2200])
# torch.Size([1])
#     NUM MINI BATCH:  11
#     FEATURES BATCH;
# tensor([[ 6.2200,  7.6100,  4.0600, -1.2000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([3.5900])
# torch.Size([1])
#     NUM MINI BATCH:  12
#     FEATURES BATCH;
# tensor([[3.5900, 6.2200, 7.6100, 4.0600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([5.2500])
# torch.Size([1])
#     NUM MINI BATCH:  13
#     FEATURES BATCH;
# tensor([[5.2500, 3.5900, 6.2200, 7.6100]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.6600])
# torch.Size([1])
#     NUM MINI BATCH:  14
#     FEATURES BATCH;
# tensor([[6.6600, 5.2500, 3.5900, 6.2200]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([3.5600])
# torch.Size([1])
#     NUM MINI BATCH:  15
#     FEATURES BATCH;
# tensor([[3.5600, 6.6600, 5.2500, 3.5900]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([7.4600])
# torch.Size([1])
#     NUM MINI BATCH:  16
#     FEATURES BATCH;
# tensor([[7.4600, 3.5600, 6.6600, 5.2500]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.0900])
# torch.Size([1])
#     NUM MINI BATCH:  17
#     FEATURES BATCH;
# tensor([[6.0900, 7.4600, 3.5600, 6.6600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([4.5700])
# torch.Size([1])
#     NUM MINI BATCH:  18
#     FEATURES BATCH;
# tensor([[4.5700, 6.0900, 7.4600, 3.5600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.1000])
# torch.Size([1])
#     NUM MINI BATCH:  19
#     FEATURES BATCH;
# tensor([[6.1000, 4.5700, 6.0900, 7.4600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([14.8400])
# torch.Size([1])
#     NUM MINI BATCH:  20
#     FEATURES BATCH;
# tensor([[14.8400,  6.1000,  4.5700,  6.0900]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([-0.0649])
# torch.Size([1])
#     NUM MINI BATCH:  21
#     FEATURES BATCH;
# tensor([[-0.0649, 14.8400,  6.1000,  4.5700]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([3.])
# torch.Size([1])
#     NUM MINI BATCH:  22
#     FEATURES BATCH;
# tensor([[ 3.0000, -0.0649, 14.8400,  6.1000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([8.8700])
# torch.Size([1])
#     NUM MINI BATCH:  23
#     FEATURES BATCH;
# tensor([[ 8.8700,  3.0000, -0.0649, 14.8400]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([2.7300])
# torch.Size([1])
#     NUM MINI BATCH:  24
#     FEATURES BATCH;
# tensor([[ 2.7300,  8.8700,  3.0000, -0.0649]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([11.6140])
# torch.Size([1])
#     NUM MINI BATCH:  25
#     FEATURES BATCH;
# tensor([[11.6140,  2.7300,  8.8700,  3.0000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([41.8600])
# torch.Size([1])
#     NUM MINI BATCH:  26
#     FEATURES BATCH;
# tensor([[41.8600, 11.6140,  2.7300,  8.8700]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([80.8900])
# torch.Size([1])
#     NUM MINI BATCH:  27
#     FEATURES BATCH;
# tensor([[80.8900, 41.8600, 11.6140,  2.7300]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([27.9500])
# torch.Size([1])
#     NUM MINI BATCH:  28
#     FEATURES BATCH;
# tensor([[27.9500, 80.8900, 41.8600, 11.6140]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([86.6700])
# torch.Size([1])
#     NUM MINI BATCH:  29
#     FEATURES BATCH;
# tensor([[86.6700, 27.9500, 80.8900, 41.8600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([76.9000])
# torch.Size([1])
#     NUM MINI BATCH:  30
#     FEATURES BATCH;
# tensor([[76.9000, 86.6700, 27.9500, 80.8900]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([99.7000])
# torch.Size([1])
#     NUM MINI BATCH:  31
#     FEATURES BATCH;
# tensor([[99.7000, 76.9000, 86.6700, 27.9500]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([67.5000])
# torch.Size([1])
#     NUM MINI BATCH:  32
#     FEATURES BATCH;
# tensor([[67.5000, 99.7000, 76.9000, 86.6700]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([121.1700])
# torch.Size([1])
#     NUM MINI BATCH:  33
#     FEATURES BATCH;
# tensor([[121.1700,  67.5000,  99.7000,  76.9000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([90.9200])
# torch.Size([1])
#     NUM MINI BATCH:  34
#     FEATURES BATCH;
# tensor([[ 90.9200, 121.1700,  67.5000,  99.7000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([119.8800])
# torch.Size([1])
#     NUM MINI BATCH:  35
#     FEATURES BATCH;
# tensor([[119.8800,  90.9200, 121.1700,  67.5000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([69.3400])
# torch.Size([1])
#
# WINDOW:  1
# FEATURES:
# tensor([[ 6.7800e+00, -5.4800e+00,  3.1400e+00,  2.4200e+00],
#         [ 6.6600e+00,  6.7800e+00, -5.4800e+00,  3.1400e+00],
#         [ 4.8300e+00,  6.6600e+00,  6.7800e+00, -5.4800e+00],
#         [-1.0100e+00,  4.8300e+00,  6.6600e+00,  6.7800e+00],
#         [-2.8400e+00, -1.0100e+00,  4.8300e+00,  6.6600e+00],
#         [ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 6.6600e+00,  4.8300e+00, -1.0100e+00, -2.8400e+00,  8.3300e+00,
#          9.2400e+00, -1.2000e+00,  4.0600e+00,  7.6100e+00,  6.2200e+00,
#          3.5900e+00,  5.2500e+00,  6.6600e+00,  3.5600e+00,  7.4600e+00,
#          6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01, -6.4877e-02,
#          3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,  4.1860e+01,
#          8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,  9.9700e+01,
#          6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,  6.9340e+01,
#          1.0542e+02])
# torch.Size([36])
#     NUM MINI BATCH:  0
#     FEATURES BATCH;
# tensor([[ 6.7800, -5.4800,  3.1400,  2.4200]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.6600])
# torch.Size([1])
#     NUM MINI BATCH:  1
#     FEATURES BATCH;
# tensor([[ 6.6600,  6.7800, -5.4800,  3.1400]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([4.8300])
# torch.Size([1])
#     NUM MINI BATCH:  2
#     FEATURES BATCH;
# tensor([[ 4.8300,  6.6600,  6.7800, -5.4800]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([-1.0100])
# torch.Size([1])
#     NUM MINI BATCH:  3
#     FEATURES BATCH;
# tensor([[-1.0100,  4.8300,  6.6600,  6.7800]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([-2.8400])
# torch.Size([1])
#     NUM MINI BATCH:  4
#     FEATURES BATCH;
# tensor([[-2.8400, -1.0100,  4.8300,  6.6600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([8.3300])
# torch.Size([1])
#     NUM MINI BATCH:  5
#     FEATURES BATCH;
# tensor([[ 8.3300, -2.8400, -1.0100,  4.8300]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([9.2400])
# torch.Size([1])
#     NUM MINI BATCH:  6
#     FEATURES BATCH;
# tensor([[ 9.2400,  8.3300, -2.8400, -1.0100]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([-1.2000])
# torch.Size([1])
#     NUM MINI BATCH:  7
#     FEATURES BATCH;
# tensor([[-1.2000,  9.2400,  8.3300, -2.8400]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([4.0600])
# torch.Size([1])
#     NUM MINI BATCH:  8
#     FEATURES BATCH;
# tensor([[ 4.0600, -1.2000,  9.2400,  8.3300]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([7.6100])
# torch.Size([1])
#     NUM MINI BATCH:  9
#     FEATURES BATCH;
# tensor([[ 7.6100,  4.0600, -1.2000,  9.2400]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.2200])
# torch.Size([1])
#     NUM MINI BATCH:  10
#     FEATURES BATCH;
# tensor([[ 6.2200,  7.6100,  4.0600, -1.2000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([3.5900])
# torch.Size([1])
#     NUM MINI BATCH:  11
#     FEATURES BATCH;
# tensor([[3.5900, 6.2200, 7.6100, 4.0600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([5.2500])
# torch.Size([1])
#     NUM MINI BATCH:  12
#     FEATURES BATCH;
# tensor([[5.2500, 3.5900, 6.2200, 7.6100]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.6600])
# torch.Size([1])
#     NUM MINI BATCH:  13
#     FEATURES BATCH;
# tensor([[6.6600, 5.2500, 3.5900, 6.2200]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([3.5600])
# torch.Size([1])
#     NUM MINI BATCH:  14
#     FEATURES BATCH;
# tensor([[3.5600, 6.6600, 5.2500, 3.5900]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([7.4600])
# torch.Size([1])
#     NUM MINI BATCH:  15
#     FEATURES BATCH;
# tensor([[7.4600, 3.5600, 6.6600, 5.2500]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.0900])
# torch.Size([1])
#     NUM MINI BATCH:  16
#     FEATURES BATCH;
# tensor([[6.0900, 7.4600, 3.5600, 6.6600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([4.5700])
# torch.Size([1])
#     NUM MINI BATCH:  17
#     FEATURES BATCH;
# tensor([[4.5700, 6.0900, 7.4600, 3.5600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([6.1000])
# torch.Size([1])
#     NUM MINI BATCH:  18
#     FEATURES BATCH;
# tensor([[6.1000, 4.5700, 6.0900, 7.4600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([14.8400])
# torch.Size([1])
#     NUM MINI BATCH:  19
#     FEATURES BATCH;
# tensor([[14.8400,  6.1000,  4.5700,  6.0900]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([-0.0649])
# torch.Size([1])
#     NUM MINI BATCH:  20
#     FEATURES BATCH;
# tensor([[-0.0649, 14.8400,  6.1000,  4.5700]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([3.])
# torch.Size([1])
#     NUM MINI BATCH:  21
#     FEATURES BATCH;
# tensor([[ 3.0000, -0.0649, 14.8400,  6.1000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([8.8700])
# torch.Size([1])
#     NUM MINI BATCH:  22
#     FEATURES BATCH;
# tensor([[ 8.8700,  3.0000, -0.0649, 14.8400]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([2.7300])
# torch.Size([1])
#     NUM MINI BATCH:  23
#     FEATURES BATCH;
# tensor([[ 2.7300,  8.8700,  3.0000, -0.0649]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([11.6140])
# torch.Size([1])
#     NUM MINI BATCH:  24
#     FEATURES BATCH;
# tensor([[11.6140,  2.7300,  8.8700,  3.0000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([41.8600])
# torch.Size([1])
#     NUM MINI BATCH:  25
#     FEATURES BATCH;
# tensor([[41.8600, 11.6140,  2.7300,  8.8700]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([80.8900])
# torch.Size([1])
#     NUM MINI BATCH:  26
#     FEATURES BATCH;
# tensor([[80.8900, 41.8600, 11.6140,  2.7300]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([27.9500])
# torch.Size([1])
#     NUM MINI BATCH:  27
#     FEATURES BATCH;
# tensor([[27.9500, 80.8900, 41.8600, 11.6140]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([86.6700])
# torch.Size([1])
#     NUM MINI BATCH:  28
#     FEATURES BATCH;
# tensor([[86.6700, 27.9500, 80.8900, 41.8600]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([76.9000])
# torch.Size([1])
#     NUM MINI BATCH:  29
#     FEATURES BATCH;
# tensor([[76.9000, 86.6700, 27.9500, 80.8900]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([99.7000])
# torch.Size([1])
#     NUM MINI BATCH:  30
#     FEATURES BATCH;
# tensor([[99.7000, 76.9000, 86.6700, 27.9500]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([67.5000])
# torch.Size([1])
#     NUM MINI BATCH:  31
#     FEATURES BATCH;
# tensor([[67.5000, 99.7000, 76.9000, 86.6700]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([121.1700])
# torch.Size([1])
#     NUM MINI BATCH:  32
#     FEATURES BATCH;
# tensor([[121.1700,  67.5000,  99.7000,  76.9000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([90.9200])
# torch.Size([1])
#     NUM MINI BATCH:  33
#     FEATURES BATCH;
# tensor([[ 90.9200, 121.1700,  67.5000,  99.7000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([119.8800])
# torch.Size([1])
#     NUM MINI BATCH:  34
#     FEATURES BATCH;
# tensor([[119.8800,  90.9200, 121.1700,  67.5000]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([69.3400])
# torch.Size([1])
#     NUM MINI BATCH:  35
#     FEATURES BATCH;
# tensor([[ 69.3400, 119.8800,  90.9200, 121.1700]])
# torch.Size([1, 4])
#     TARGET BATCH;
# tensor([105.4200])
# torch.Size([1])

# %% [markdown]
# # Validation rolling sample window

# %%
# read processed data
df = pd.read_csv("../data/processed/tidy_df.csv", index_col=[0, 1, 2])

# empty list for dataframes
y_test_list = []
y_hat_umlp = []

i = df.index.get_level_values(0).unique()[0]
print(i)

# y : "EPS"
y = df.loc[pd.IndexSlice[i, :, :], "EPS"]

# x, exogenous regressors : 'INV', 'AR', 'CAPX', 'GM', 'SA', 'ETR', 'LF'
#     x = df.loc[pd.IndexSlice[i, :, :], ['INV', 'AR', 'CAPX', 'GM', 'SA', 'ETR', 'LF']]

# Unlike statsmodel SARIMA package, NN needs to prepare lagged inputs manually if needed.
# y_lag and x_lag (lag 4 for now)
num_lag = 4
y_lag = lag(y, num_lag, drop_nan=False, reset_index=False)
#     x_lag = lag(x, num_lag, drop_nan=False, reset_index=False)

# Redefine data name as target (y) and feature (y_lag) (explanatory variable, predictor)
target = y
feature = y_lag

# save simple test data series
_, target_test_dataset = train_test_split(target, test_size=12)
_, feature_test_dataset = train_test_split(feature, test_size=12)

# drop nan caused by lag()
feature = feature.dropna(axis=0)
target = target[feature.index]

# setting torch
dtype = torch.float # double float problem in layer 
device = torch.device("cpu")

# Make data to torch.tensor
target = torch.tensor(target.values, dtype=dtype)
feature = torch.tensor(feature.values, dtype=dtype)
target_test_dataset = torch.tensor(target_test_dataset.values, dtype=dtype)
feature_test_dataset = torch.tensor(feature_test_dataset.values, dtype=dtype)
# Out:
# あらた

# %%
# rolling window data preparation with validation

### ! Hyper-Parameter ! ##########################################################
# all period: 48 (train 24, valid 12, test 12)
test_window = len(target_test_dataset)
print("test window: ", test_window)

valid_window = test_window
print("valid window: ", valid_window)

train_window = len(target) - test_window - valid_window
print("train window: ", train_window)

##################################################################################
# Out:
# test window:  12
# valid window:  12
# train window:  24

# %%
train_valid_dataset = TimeSeriesDataset(feature, target, train_window+valid_window)
print("len of train_valid_dataset: ", len(train_valid_dataset))
train_valid_loader = torch.utils.data.DataLoader(train_valid_dataset, batch_size=1, shuffle=False)

for num_window, (feature_train_valid, target_train_valid) in enumerate(train_valid_dataset):
#     print(feature_train.size(), target_train.size())
#     feature_train_valid = feature_train_valid[0] # extract single window batch
#     target_train_valid = target_train_valid[0] # extract single window batch
#     if (num_window == 0) | (num_window == 1):
    print("")
    print("WINDOW: ", num_window)
    print("FEATURES: ")
    print(feature_train_valid)
    print(feature_train_valid.size())
    print("TARGET: ")
    print(target_train_valid)
    print(target_train_valid.size())
        
#     train_dataset = TimeSeriesDataset(feature_train_valid, target_train_valid, train_window)
        
#     # mini-batch loader
#     batch_dataset = TimeSeriesDataset(feature_train, target_train, train_window=None)
#     minibatch_loader = torch.utils.data.DataLoader(batch_dataset, batch_size=1, shuffle=False)
    
#     for num_mini_batch, (feature_train_mini_batch, target_train_mini_batch) in enumerate(minibatch_loader):
#         if (num_window == 0) | (num_window == 1):
#             print("    NUM MINI BATCH: ", num_mini_batch)
#             print("    FEATURES BATCH; ")
#             print(feature_train_mini_batch)
#             print(feature_train_mini_batch.size())
#             print("    TARGET BATCH; ")
#             print(target_train_mini_batch)
#             print(target_train_mini_batch.size())
# Out:
# len of train_valid_dataset:  12
#
# WINDOW:  0
# FEATURES:
# tensor([[-5.4800e+00,  3.1400e+00,  2.4200e+00,  2.6600e+00],
#         [ 6.7800e+00, -5.4800e+00,  3.1400e+00,  2.4200e+00],
#         [ 6.6600e+00,  6.7800e+00, -5.4800e+00,  3.1400e+00],
#         [ 4.8300e+00,  6.6600e+00,  6.7800e+00, -5.4800e+00],
#         [-1.0100e+00,  4.8300e+00,  6.6600e+00,  6.7800e+00],
#         [-2.8400e+00, -1.0100e+00,  4.8300e+00,  6.6600e+00],
#         [ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 6.7800e+00,  6.6600e+00,  4.8300e+00, -1.0100e+00, -2.8400e+00,
#          8.3300e+00,  9.2400e+00, -1.2000e+00,  4.0600e+00,  7.6100e+00,
#          6.2200e+00,  3.5900e+00,  5.2500e+00,  6.6600e+00,  3.5600e+00,
#          7.4600e+00,  6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01,
#         -6.4877e-02,  3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,
#          4.1860e+01,  8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,
#          9.9700e+01,  6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,
#          6.9340e+01])
# torch.Size([36])
#
# WINDOW:  1
# FEATURES:
# tensor([[ 6.7800e+00, -5.4800e+00,  3.1400e+00,  2.4200e+00],
#         [ 6.6600e+00,  6.7800e+00, -5.4800e+00,  3.1400e+00],
#         [ 4.8300e+00,  6.6600e+00,  6.7800e+00, -5.4800e+00],
#         [-1.0100e+00,  4.8300e+00,  6.6600e+00,  6.7800e+00],
#         [-2.8400e+00, -1.0100e+00,  4.8300e+00,  6.6600e+00],
#         [ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 6.6600e+00,  4.8300e+00, -1.0100e+00, -2.8400e+00,  8.3300e+00,
#          9.2400e+00, -1.2000e+00,  4.0600e+00,  7.6100e+00,  6.2200e+00,
#          3.5900e+00,  5.2500e+00,  6.6600e+00,  3.5600e+00,  7.4600e+00,
#          6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01, -6.4877e-02,
#          3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,  4.1860e+01,
#          8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,  9.9700e+01,
#          6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,  6.9340e+01,
#          1.0542e+02])
# torch.Size([36])
#
# WINDOW:  2
# FEATURES:
# tensor([[ 6.6600e+00,  6.7800e+00, -5.4800e+00,  3.1400e+00],
#         [ 4.8300e+00,  6.6600e+00,  6.7800e+00, -5.4800e+00],
#         [-1.0100e+00,  4.8300e+00,  6.6600e+00,  6.7800e+00],
#         [-2.8400e+00, -1.0100e+00,  4.8300e+00,  6.6600e+00],
#         [ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 4.8300e+00, -1.0100e+00, -2.8400e+00,  8.3300e+00,  9.2400e+00,
#         -1.2000e+00,  4.0600e+00,  7.6100e+00,  6.2200e+00,  3.5900e+00,
#          5.2500e+00,  6.6600e+00,  3.5600e+00,  7.4600e+00,  6.0900e+00,
#          4.5700e+00,  6.1000e+00,  1.4840e+01, -6.4877e-02,  3.0000e+00,
#          8.8700e+00,  2.7300e+00,  1.1614e+01,  4.1860e+01,  8.0890e+01,
#          2.7950e+01,  8.6670e+01,  7.6900e+01,  9.9700e+01,  6.7500e+01,
#          1.2117e+02,  9.0920e+01,  1.1988e+02,  6.9340e+01,  1.0542e+02,
#          9.0440e+01])
# torch.Size([36])
#
# WINDOW:  3
# FEATURES:
# tensor([[ 4.8300e+00,  6.6600e+00,  6.7800e+00, -5.4800e+00],
#         [-1.0100e+00,  4.8300e+00,  6.6600e+00,  6.7800e+00],
#         [-2.8400e+00, -1.0100e+00,  4.8300e+00,  6.6600e+00],
#         [ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02]])
# torch.Size([36, 4])
# TARGET:
# tensor([-1.0100e+00, -2.8400e+00,  8.3300e+00,  9.2400e+00, -1.2000e+00,
#          4.0600e+00,  7.6100e+00,  6.2200e+00,  3.5900e+00,  5.2500e+00,
#          6.6600e+00,  3.5600e+00,  7.4600e+00,  6.0900e+00,  4.5700e+00,
#          6.1000e+00,  1.4840e+01, -6.4877e-02,  3.0000e+00,  8.8700e+00,
#          2.7300e+00,  1.1614e+01,  4.1860e+01,  8.0890e+01,  2.7950e+01,
#          8.6670e+01,  7.6900e+01,  9.9700e+01,  6.7500e+01,  1.2117e+02,
#          9.0920e+01,  1.1988e+02,  6.9340e+01,  1.0542e+02,  9.0440e+01,
#          1.0624e+02])
# torch.Size([36])
#
# WINDOW:  4
# FEATURES:
# tensor([[-1.0100e+00,  4.8300e+00,  6.6600e+00,  6.7800e+00],
#         [-2.8400e+00, -1.0100e+00,  4.8300e+00,  6.6600e+00],
#         [ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01]])
# torch.Size([36, 4])
# TARGET:
# tensor([-2.8400e+00,  8.3300e+00,  9.2400e+00, -1.2000e+00,  4.0600e+00,
#          7.6100e+00,  6.2200e+00,  3.5900e+00,  5.2500e+00,  6.6600e+00,
#          3.5600e+00,  7.4600e+00,  6.0900e+00,  4.5700e+00,  6.1000e+00,
#          1.4840e+01, -6.4877e-02,  3.0000e+00,  8.8700e+00,  2.7300e+00,
#          1.1614e+01,  4.1860e+01,  8.0890e+01,  2.7950e+01,  8.6670e+01,
#          7.6900e+01,  9.9700e+01,  6.7500e+01,  1.2117e+02,  9.0920e+01,
#          1.1988e+02,  6.9340e+01,  1.0542e+02,  9.0440e+01,  1.0624e+02,
#          9.9220e+01])
# torch.Size([36])
#
# WINDOW:  5
# FEATURES:
# tensor([[-2.8400e+00, -1.0100e+00,  4.8300e+00,  6.6600e+00],
#         [ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 8.3300e+00,  9.2400e+00, -1.2000e+00,  4.0600e+00,  7.6100e+00,
#          6.2200e+00,  3.5900e+00,  5.2500e+00,  6.6600e+00,  3.5600e+00,
#          7.4600e+00,  6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01,
#         -6.4877e-02,  3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,
#          4.1860e+01,  8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,
#          9.9700e+01,  6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,
#          6.9340e+01,  1.0542e+02,  9.0440e+01,  1.0624e+02,  9.9220e+01,
#          1.1685e+02])
# torch.Size([36])
#
# WINDOW:  6
# FEATURES:
# tensor([[ 8.3300e+00, -2.8400e+00, -1.0100e+00,  4.8300e+00],
#         [ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 9.2400e+00, -1.2000e+00,  4.0600e+00,  7.6100e+00,  6.2200e+00,
#          3.5900e+00,  5.2500e+00,  6.6600e+00,  3.5600e+00,  7.4600e+00,
#          6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01, -6.4877e-02,
#          3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,  4.1860e+01,
#          8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,  9.9700e+01,
#          6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,  6.9340e+01,
#          1.0542e+02,  9.0440e+01,  1.0624e+02,  9.9220e+01,  1.1685e+02,
#          1.0176e+02])
# torch.Size([36])
#
# WINDOW:  7
# FEATURES:
# tensor([[ 9.2400e+00,  8.3300e+00, -2.8400e+00, -1.0100e+00],
#         [-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02]])
# torch.Size([36, 4])
# TARGET:
# tensor([-1.2000e+00,  4.0600e+00,  7.6100e+00,  6.2200e+00,  3.5900e+00,
#          5.2500e+00,  6.6600e+00,  3.5600e+00,  7.4600e+00,  6.0900e+00,
#          4.5700e+00,  6.1000e+00,  1.4840e+01, -6.4877e-02,  3.0000e+00,
#          8.8700e+00,  2.7300e+00,  1.1614e+01,  4.1860e+01,  8.0890e+01,
#          2.7950e+01,  8.6670e+01,  7.6900e+01,  9.9700e+01,  6.7500e+01,
#          1.2117e+02,  9.0920e+01,  1.1988e+02,  6.9340e+01,  1.0542e+02,
#          9.0440e+01,  1.0624e+02,  9.9220e+01,  1.1685e+02,  1.0176e+02,
#          1.1393e+02])
# torch.Size([36])
#
# WINDOW:  8
# FEATURES:
# tensor([[-1.2000e+00,  9.2400e+00,  8.3300e+00, -2.8400e+00],
#         [ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 4.0600e+00,  7.6100e+00,  6.2200e+00,  3.5900e+00,  5.2500e+00,
#          6.6600e+00,  3.5600e+00,  7.4600e+00,  6.0900e+00,  4.5700e+00,
#          6.1000e+00,  1.4840e+01, -6.4877e-02,  3.0000e+00,  8.8700e+00,
#          2.7300e+00,  1.1614e+01,  4.1860e+01,  8.0890e+01,  2.7950e+01,
#          8.6670e+01,  7.6900e+01,  9.9700e+01,  6.7500e+01,  1.2117e+02,
#          9.0920e+01,  1.1988e+02,  6.9340e+01,  1.0542e+02,  9.0440e+01,
#          1.0624e+02,  9.9220e+01,  1.1685e+02,  1.0176e+02,  1.1393e+02,
#          7.9900e+01])
# torch.Size([36])
#
# WINDOW:  9
# FEATURES:
# tensor([[ 4.0600e+00, -1.2000e+00,  9.2400e+00,  8.3300e+00],
#         [ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01],
#         [ 7.9900e+01,  1.1393e+02,  1.0176e+02,  1.1685e+02]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 7.6100e+00,  6.2200e+00,  3.5900e+00,  5.2500e+00,  6.6600e+00,
#          3.5600e+00,  7.4600e+00,  6.0900e+00,  4.5700e+00,  6.1000e+00,
#          1.4840e+01, -6.4877e-02,  3.0000e+00,  8.8700e+00,  2.7300e+00,
#          1.1614e+01,  4.1860e+01,  8.0890e+01,  2.7950e+01,  8.6670e+01,
#          7.6900e+01,  9.9700e+01,  6.7500e+01,  1.2117e+02,  9.0920e+01,
#          1.1988e+02,  6.9340e+01,  1.0542e+02,  9.0440e+01,  1.0624e+02,
#          9.9220e+01,  1.1685e+02,  1.0176e+02,  1.1393e+02,  7.9900e+01,
#          1.4523e+02])
# torch.Size([36])
#
# WINDOW:  10
# FEATURES:
# tensor([[ 7.6100e+00,  4.0600e+00, -1.2000e+00,  9.2400e+00],
#         [ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01],
#         [ 7.9900e+01,  1.1393e+02,  1.0176e+02,  1.1685e+02],
#         [ 1.4523e+02,  7.9900e+01,  1.1393e+02,  1.0176e+02]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 6.2200e+00,  3.5900e+00,  5.2500e+00,  6.6600e+00,  3.5600e+00,
#          7.4600e+00,  6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01,
#         -6.4877e-02,  3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,
#          4.1860e+01,  8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,
#          9.9700e+01,  6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,
#          6.9340e+01,  1.0542e+02,  9.0440e+01,  1.0624e+02,  9.9220e+01,
#          1.1685e+02,  1.0176e+02,  1.1393e+02,  7.9900e+01,  1.4523e+02,
#          1.2068e+02])
# torch.Size([36])
#
# WINDOW:  11
# FEATURES:
# tensor([[ 6.2200e+00,  7.6100e+00,  4.0600e+00, -1.2000e+00],
#         [ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01],
#         [ 7.9900e+01,  1.1393e+02,  1.0176e+02,  1.1685e+02],
#         [ 1.4523e+02,  7.9900e+01,  1.1393e+02,  1.0176e+02],
#         [ 1.2068e+02,  1.4523e+02,  7.9900e+01,  1.1393e+02]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 3.5900e+00,  5.2500e+00,  6.6600e+00,  3.5600e+00,  7.4600e+00,
#          6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01, -6.4877e-02,
#          3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,  4.1860e+01,
#          8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,  9.9700e+01,
#          6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,  6.9340e+01,
#          1.0542e+02,  9.0440e+01,  1.0624e+02,  9.9220e+01,  1.1685e+02,
#          1.0176e+02,  1.1393e+02,  7.9900e+01,  1.4523e+02,  1.2068e+02,
#          1.5335e+02])
# torch.Size([36])
#
# WINDOW:  12
# FEATURES:
# tensor([[ 3.5900e+00,  6.2200e+00,  7.6100e+00,  4.0600e+00],
#         [ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01],
#         [ 7.9900e+01,  1.1393e+02,  1.0176e+02,  1.1685e+02],
#         [ 1.4523e+02,  7.9900e+01,  1.1393e+02,  1.0176e+02],
#         [ 1.2068e+02,  1.4523e+02,  7.9900e+01,  1.1393e+02],
#         [ 1.5335e+02,  1.2068e+02,  1.4523e+02,  7.9900e+01]])
# torch.Size([36, 4])
# TARGET:
# tensor([ 5.2500e+00,  6.6600e+00,  3.5600e+00,  7.4600e+00,  6.0900e+00,
#          4.5700e+00,  6.1000e+00,  1.4840e+01, -6.4877e-02,  3.0000e+00,
#          8.8700e+00,  2.7300e+00,  1.1614e+01,  4.1860e+01,  8.0890e+01,
#          2.7950e+01,  8.6670e+01,  7.6900e+01,  9.9700e+01,  6.7500e+01,
#          1.2117e+02,  9.0920e+01,  1.1988e+02,  6.9340e+01,  1.0542e+02,
#          9.0440e+01,  1.0624e+02,  9.9220e+01,  1.1685e+02,  1.0176e+02,
#          1.1393e+02,  7.9900e+01,  1.4523e+02,  1.2068e+02,  1.5335e+02,
#          6.1403e+01])
# torch.Size([36])
#
# WINDOW:  13
# FEATURES:
# tensor([[ 5.2500e+00,  3.5900e+00,  6.2200e+00,  7.6100e+00],
#         [ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01],
#         [ 7.9900e+01,  1.1393e+02,  1.0176e+02,  1.1685e+02],
#         [ 1.4523e+02,  7.9900e+01,  1.1393e+02,  1.0176e+02],
#         [ 1.2068e+02,  1.4523e+02,  7.9900e+01,  1.1393e+02],
#         [ 1.5335e+02,  1.2068e+02,  1.4523e+02,  7.9900e+01]])
# torch.Size([35, 4])
# TARGET:
# tensor([ 6.6600e+00,  3.5600e+00,  7.4600e+00,  6.0900e+00,  4.5700e+00,
#          6.1000e+00,  1.4840e+01, -6.4877e-02,  3.0000e+00,  8.8700e+00,
#          2.7300e+00,  1.1614e+01,  4.1860e+01,  8.0890e+01,  2.7950e+01,
#          8.6670e+01,  7.6900e+01,  9.9700e+01,  6.7500e+01,  1.2117e+02,
#          9.0920e+01,  1.1988e+02,  6.9340e+01,  1.0542e+02,  9.0440e+01,
#          1.0624e+02,  9.9220e+01,  1.1685e+02,  1.0176e+02,  1.1393e+02,
#          7.9900e+01,  1.4523e+02,  1.2068e+02,  1.5335e+02,  6.1403e+01])
# torch.Size([35])
#
# WINDOW:  14
# FEATURES:
# tensor([[ 6.6600e+00,  5.2500e+00,  3.5900e+00,  6.2200e+00],
#         [ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01],
#         [ 7.9900e+01,  1.1393e+02,  1.0176e+02,  1.1685e+02],
#         [ 1.4523e+02,  7.9900e+01,  1.1393e+02,  1.0176e+02],
#         [ 1.2068e+02,  1.4523e+02,  7.9900e+01,  1.1393e+02],
#         [ 1.5335e+02,  1.2068e+02,  1.4523e+02,  7.9900e+01]])
# torch.Size([34, 4])
# TARGET:
# tensor([ 3.5600e+00,  7.4600e+00,  6.0900e+00,  4.5700e+00,  6.1000e+00,
#          1.4840e+01, -6.4877e-02,  3.0000e+00,  8.8700e+00,  2.7300e+00,
#          1.1614e+01,  4.1860e+01,  8.0890e+01,  2.7950e+01,  8.6670e+01,
#          7.6900e+01,  9.9700e+01,  6.7500e+01,  1.2117e+02,  9.0920e+01,
#          1.1988e+02,  6.9340e+01,  1.0542e+02,  9.0440e+01,  1.0624e+02,
#          9.9220e+01,  1.1685e+02,  1.0176e+02,  1.1393e+02,  7.9900e+01,
#          1.4523e+02,  1.2068e+02,  1.5335e+02,  6.1403e+01])
# torch.Size([34])
#
# WINDOW:  15
# FEATURES:
# tensor([[ 3.5600e+00,  6.6600e+00,  5.2500e+00,  3.5900e+00],
#         [ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01],
#         [ 7.9900e+01,  1.1393e+02,  1.0176e+02,  1.1685e+02],
#         [ 1.4523e+02,  7.9900e+01,  1.1393e+02,  1.0176e+02],
#         [ 1.2068e+02,  1.4523e+02,  7.9900e+01,  1.1393e+02],
#         [ 1.5335e+02,  1.2068e+02,  1.4523e+02,  7.9900e+01]])
# torch.Size([33, 4])
# TARGET:
# tensor([ 7.4600e+00,  6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01,
#         -6.4877e-02,  3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,
#          4.1860e+01,  8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,
#          9.9700e+01,  6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,
#          6.9340e+01,  1.0542e+02,  9.0440e+01,  1.0624e+02,  9.9220e+01,
#          1.1685e+02,  1.0176e+02,  1.1393e+02,  7.9900e+01,  1.4523e+02,
#          1.2068e+02,  1.5335e+02,  6.1403e+01])
# torch.Size([33])
#
# WINDOW:  16
# FEATURES:
# tensor([[ 7.4600e+00,  3.5600e+00,  6.6600e+00,  5.2500e+00],
#         [ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
#         [ 1.1614e+01,  2.7300e+00,  8.8700e+00,  3.0000e+00],
#         [ 4.1860e+01,  1.1614e+01,  2.7300e+00,  8.8700e+00],
#         [ 8.0890e+01,  4.1860e+01,  1.1614e+01,  2.7300e+00],
#         [ 2.7950e+01,  8.0890e+01,  4.1860e+01,  1.1614e+01],
#         [ 8.6670e+01,  2.7950e+01,  8.0890e+01,  4.1860e+01],
#         [ 7.6900e+01,  8.6670e+01,  2.7950e+01,  8.0890e+01],
#         [ 9.9700e+01,  7.6900e+01,  8.6670e+01,  2.7950e+01],
#         [ 6.7500e+01,  9.9700e+01,  7.6900e+01,  8.6670e+01],
#         [ 1.2117e+02,  6.7500e+01,  9.9700e+01,  7.6900e+01],
#         [ 9.0920e+01,  1.2117e+02,  6.7500e+01,  9.9700e+01],
#         [ 1.1988e+02,  9.0920e+01,  1.2117e+02,  6.7500e+01],
#         [ 6.9340e+01,  1.1988e+02,  9.0920e+01,  1.2117e+02],
#         [ 1.0542e+02,  6.9340e+01,  1.1988e+02,  9.0920e+01],
#         [ 9.0440e+01,  1.0542e+02,  6.9340e+01,  1.1988e+02],
#         [ 1.0624e+02,  9.0440e+01,  1.0542e+02,  6.9340e+01],
#         [ 9.9220e+01,  1.0624e+02,  9.0440e+01,  1.0542e+02],
#         [ 1.1685e+02,  9.9220e+01,  1.0624e+02,  9.0440e+01],
#         [ 1.0176e+02,  1.1685e+02,  9.9220e+01,  1.0624e+02],
#         [ 1.1393e+02,  1.0176e+02,  1.1685e+02,  9.9220e+01],
#         [ 7.9900e+01,  1.1393e+02,  1.0176e+02,  1.1685e+02],
#         [ 1.4523e+02,  7.9900e+01,  1.1393e+02,  1.0176e+02],
#         [ 1.2068e+02,  1.4523e+02,  7.9900e+01,  1.1393e+02],
#         [ 1.5335e+02,  1.2068e+02,  1.4523e+02,  7.9900e+01]])
# torch.Size([32, 4])
# TARGET:
# tensor([ 6.0900e+00,  4.5700e+00,  6.1000e+00,  1.4840e+01, -6.4877e-02,
#          3.0000e+00,  8.8700e+00,  2.7300e+00,  1.1614e+01,  4.1860e+01,
#          8.0890e+01,  2.7950e+01,  8.6670e+01,  7.6900e+01,  9.9700e+01,
#          6.7500e+01,  1.2117e+02,  9.0920e+01,  1.1988e+02,  6.9340e+01,
#          1.0542e+02,  9.0440e+01,  1.0624e+02,  9.9220e+01,  1.1685e+02,
#          1.0176e+02,  1.1393e+02,  7.9900e+01,  1.4523e+02,  1.2068e+02,
#          1.5335e+02,  6.1403e+01])
# torch.Size([32])
#
# WINDOW:  17
# FEATURES:
# tensor([[ 6.0900e+00,  7.4600e+00,  3.5600e+00,  6.6600e+00],
#         [ 4.5700e+00,  6.0900e+00,  7.4600e+00,  3.5600e+00],
#         [ 6.1000e+00,  4.5700e+00,  6.0900e+00,  7.4600e+00],
#         [ 1.4840e+01,  6.1000e+00,  4.5700e+00,  6.0900e+00],
#         [-6.4877e-02,  1.4840e+01,  6.1000e+00,  4.5700e+00],
#         [ 3.0000e+00, -6.4877e-02,  1.4840e+01,  6.1000e+00],
#         [ 8.8700e+00,  3.0000e+00, -6.4877e-02,  1.4840e+01],
#         [ 2.7300e+00,  8.8700e+00,  3.0000e+00, -6.4877e-02],
# ...
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2056
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2057
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2058
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2059
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2060
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2061
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2062
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2063
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2064
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2065
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2066
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2067
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2068
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2069
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2070
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2071
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2072
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2073
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2074
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2075
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2076
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2077
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2078
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2079
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2080
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2081
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2082
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2083
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2084
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2085
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2086
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2087
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2088
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2089
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2090
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2091
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2092
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2093
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2094
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2095
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2096
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2097
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2098
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2099
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2100
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2101
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2102
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2103
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2104
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2105
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2106
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2107
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2108
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2109
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2110
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2111
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2112
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2113
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2114
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2115
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2116
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2117
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2118
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2119
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2120
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2121
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2122
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2123
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2124
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2125
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2126
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2127
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2128
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2129
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2130
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2131
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2132
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2133
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2134
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2135
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2136
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2137
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2138
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2139
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2140
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2141
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2142
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2143
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2144
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2145
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2146
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2147
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2148
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2149
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2150
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2151
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2152
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2153
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2154
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2155
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2156
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2157
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2158
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2159
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2160
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2161
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2162
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2163
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2164
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2165
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2166
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2167
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2168
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2169
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2170
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2171
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2172
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2173
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2174
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2175
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2176
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2177
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2178
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2179
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2180
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2181
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2182
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2183
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2184
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2185
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2186
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2187
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2188
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:  2189
# FEATURES:
# tensor([], size=(0, 4))
# torch.Size([0, 4])
# TARGET:
# tensor([])
# torch.Size([0])
#
# WINDOW:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-db2ff45aa1aa> in <module>
#       9 #     if (num_window == 0) | (num_window == 1):
#      10     print("")
# ---> 11     print("WINDOW: ", num_window)
#      12     print("FEATURES: ")
#      13     print(feature_train_valid)
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /usr/local/lib/python3.8/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.8/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
